# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
olympics = pd.read_csv("olympics.csv")
olympics
# Out:
#                                               No_Summer  First_set  \
# Afghanistan (AFG)                                    13          0
# Algeria (ALG)                                        12          5
# Argentina (ARG)                                      23         18
# Armenia (ARM)                                         5          1
# Australasia (ANZ) [ANZ]                               2          3
# ...                                                 ...        ...
# Independent Olympic Participants (IOP) [IOP]          1          0
# Zambia (ZAM) [ZAM]                                   12          0
# Zimbabwe (ZIM) [ZIM]                                 12          3
# Mixed team (ZZX) [ZZX]                                3          8
# Totals                                               27       4809
#
#                                               Second_Set  Third_Set  Total  \
# Afghanistan (AFG)                                      0          2      2
# ...

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147 entries, Afghanistan (AFG) to Totals
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No_Summer       147 non-null    int64
#  1   First_set       147 non-null    int64
#  2   Second_Set      147 non-null    int64
#  3   Third_Set       147 non-null    int64
#  4   Total           147 non-null    int64
#  5   No_Winter       147 non-null    int64
#  6   First_set.1     147 non-null    int64
#  7   Second_Set.1    147 non-null    int64
#  8   Third_Set.1     147 non-null    int64
#  9   Total.1         147 non-null    int64
#  10  No_Games        147 non-null    int64
#  11  First_set.2     147 non-null    int64
#  12  Second_Set.2    147 non-null    int64
#  13  Third_Set.2     147 non-null    int64
#  14  Combined total  147 non-null    int64
# dtypes: int64(15)
# memory usage: 18.4+ KB

# %%
olympics.describe()
# Out:
#         No_Summer    First_set   Second_Set    Third_Set         Total  \
# count  147.000000   147.000000   147.000000   147.000000    147.000000
# mean    13.476190    65.428571    64.965986    69.795918    200.190476
# std      7.072359   405.549990   399.309960   427.187344   1231.306297
# min      1.000000     0.000000     0.000000     0.000000      0.000000
# 25%      8.000000     0.000000     1.000000     1.000000      2.000000
# 50%     13.000000     3.000000     4.000000     6.000000     12.000000
# 75%     18.500000    24.000000    28.000000    29.000000     86.000000
# max     27.000000  4809.000000  4775.000000  5130.000000  14714.000000
#
#         No_Winter  First_set.1  Second_Set.1  Third_Set.1      Total.1  \
# count  147.000000   147.000000    147.000000   147.000000   147.000000
# mean     6.700680    13.047619     13.034014    12.897959    38.979592
# std      7.433186    80.799204     80.634421    79.588388   240.917324
# ...

# %%
min(olympics)
# Out:
# 'Combined total'

# %%
max(olympics)
# Out:
# 'Total.1'

# %%
olympics.shape
# Out:
# (147, 15)

# %%
olympics.size
# Out:
# 2205

# %%
olympics.head(n=3)
# Out:
#                    No_Summer  First_set  Second_Set  Third_Set  Total  \
# Afghanistan (AFG)         13          0           0          2      2
# Algeria (ALG)             12          5           2          8     15
# Argentina (ARG)           23         18          24         28     70
#
#                    No_Winter  First_set.1  Second_Set.1  Third_Set.1  Total.1  \
# Afghanistan (AFG)          0            0             0            0        0
# Algeria (ALG)              3            0             0            0        0
# Argentina (ARG)           18            0             0            0        0
#
#                    No_Games  First_set.2  Second_Set.2  Third_Set.2  \
# Afghanistan (AFG)        13            0             0            2
# Algeria (ALG)            15            5             2            8
# Argentina (ARG)          41           18            24           28
#
#                    Combined total
# Afghanistan (AFG)               2
# ...

# %%
olympics.index
# Out:
# Index(['Afghanistan (AFG)', 'Algeria (ALG)', 'Argentina (ARG)',
#        'Armenia (ARM)', 'Australasia (ANZ) [ANZ]', 'Australia (AUS) [AUS] [Z]',
#        'Austria (AUT)', 'Azerbaijan (AZE)', 'Bahamas (BAH)', 'Bahrain (BRN)',
#        ...
#        'Uzbekistan (UZB)', 'Venezuela (VEN)', 'Vietnam (VIE)',
#        'Virgin Islands (ISV)', 'Yugoslavia (YUG) [YUG]',
#        'Independent Olympic Participants (IOP) [IOP]', 'Zambia (ZAM) [ZAM]',
#        'Zimbabwe (ZIM) [ZIM]', 'Mixed team (ZZX) [ZZX]', 'Totals'],
#       dtype='object', length=147)

# %%
olympics.columns
# Out:
# Index(['No_Summer', 'First_set', 'Second_Set', 'Third_Set', 'Total',
#        'No_Winter', 'First_set.1', 'Second_Set.1', 'Third_Set.1', 'Total.1',
#        'No_Games', 'First_set.2', 'Second_Set.2', 'Third_Set.2',
#        'Combined total'],
#       dtype='object')

# %%
olympics.min()
# Out:
# No_Summer         1
# First_set         0
# Second_Set        0
# Third_Set         0
# Total             0
# No_Winter         0
# First_set.1       0
# Second_Set.1      0
# Third_Set.1       0
# Total.1           0
# No_Games          1
# First_set.2       0
# Second_Set.2      0
# Third_Set.2       0
# Combined total    1
# dtype: int64

# %%
olympics.mean()
# Out:
# No_Summer          13.476190
# First_set          65.428571
# Second_Set         64.965986
# Third_Set          69.795918
# Total             200.190476
# No_Winter           6.700680
# First_set.1        13.047619
# Second_Set.1       13.034014
# Third_Set.1        12.897959
# Total.1            38.979592
# No_Games           20.176871
# First_set.2        78.476190
# Second_Set.2       78.000000
# Third_Set.2        82.693878
# Combined total    239.170068
# dtype: float64

# %%
olympics.mean().sort_values()
# Out:
# No_Winter           6.700680
# Third_Set.1        12.897959
# Second_Set.1       13.034014
# First_set.1        13.047619
# No_Summer          13.476190
# No_Games           20.176871
# Total.1            38.979592
# Second_Set         64.965986
# First_set          65.428571
# Third_Set          69.795918
# Second_Set.2       78.000000
# First_set.2        78.476190
# Third_Set.2        82.693878
# Total             200.190476
# Combined total    239.170068
# dtype: float64

# %%
olympics["No_Winter"]
# Out:
# Afghanistan (AFG)                                0
# Algeria (ALG)                                    3
# Argentina (ARG)                                 18
# Armenia (ARM)                                    6
# Australasia (ANZ) [ANZ]                          0
#                                                 ..
# Independent Olympic Participants (IOP) [IOP]     0
# Zambia (ZAM) [ZAM]                               0
# Zimbabwe (ZIM) [ZIM]                             1
# Mixed team (ZZX) [ZZX]                           0
# Totals                                          22
# Name: No_Winter, Length: 147, dtype: int64

# %%
olympics[["No_Winter", "No_Summer"]]
# Out:
#                                               No_Winter  No_Summer
# Afghanistan (AFG)                                     0         13
# Algeria (ALG)                                         3         12
# Argentina (ARG)                                      18         23
# Armenia (ARM)                                         6          5
# Australasia (ANZ) [ANZ]                               0          2
# ...                                                 ...        ...
# Independent Olympic Participants (IOP) [IOP]          0          1
# Zambia (ZAM) [ZAM]                                    0         12
# Zimbabwe (ZIM) [ZIM]                                  1         12
# Mixed team (ZZX) [ZZX]                                0          3
# Totals                                               22         27
#
# [147 rows x 2 columns]

# %%
x = pd.DataFrame(olympics, columns=["No_Summer"])
y = pd.DataFrame(olympics, columns=['No_Winter'])

# %%
print(x)
# Out:
#                                               No_Summer
# Afghanistan (AFG)                                    13
# Algeria (ALG)                                        12
# Argentina (ARG)                                      23
# Armenia (ARM)                                         5
# Australasia (ANZ) [ANZ]                               2
# ...                                                 ...
# Independent Olympic Participants (IOP) [IOP]          1
# Zambia (ZAM) [ZAM]                                   12
# Zimbabwe (ZIM) [ZIM]                                 12
# Mixed team (ZZX) [ZZX]                                3
# Totals                                               27
#
# [147 rows x 1 columns]

# %%
plt.figure(figsize=(40, 20))
plt.scatter(x, y, alpha=0.3)
plt.title("Summer vs. Winter games")
plt.xlabel('Summer')
plt.ylabel('Winter')
plt.ylim(0, 40)
plt.xlim(0, 40)
# Out:
# (0.0, 40.0)
